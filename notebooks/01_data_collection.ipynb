# %% [markdown]
# # 01. Data Collection
#
# ## 아파트 실거래가 원본 데이터 수집 기록
#
# 이 노트북은 아파트 실거래가 원본 데이터의 수집 조건과 파일 정보를 기록하기 위한 문서이다.
#
# ### 다운로드 조건
#
# | 항목 | 내용 |
# | --- | --- |
# | 데이터 출처 | 국토교통부 실거래가 공개시스템 자료제공 |
# | 데이터 유형 | 아파트 매매 실거래가 |
# | 지역 | 서울특별시 |
# | 계약일자 범위 | 2025-01-01 ~ 2025-12-31 |
# | 파일 형식 | CSV |
# | 원본 파일명 | `아파트(매매)_실거래가_20260527151853.csv` |
# | 저장 위치 | `data/raw/아파트(매매)_실거래가_20260527151853.csv` |
#
# ### 관리 원칙
#
# - `data/raw/`에 저장한 원본 데이터는 직접 수정하지 않는다.
# - 전처리 결과는 `data/interim/` 또는 `data/processed/`에 별도 파일로 저장한다.
# - 원본 데이터 파일은 GitHub에 업로드하지 않고, 다운로드 조건만 문서화한다.
# - 같은 데이터를 다시 받을 수 있도록 출처, 기간, 지역, 파일명을 반드시 기록한다.

# %%
from pathlib import Path

raw_data_path = Path('../data/raw/아파트(매매)_실거래가_20260527151853.csv')
raw_data_path

# %%
raw_data_path.exists()
